# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
data = pd.read_excel("data.xlsx")

# %%
data.sample(7)
# Out:
#                 timestamp  user ID       ip_address  \
# 2089  2017-10-06 06:05:51     1739   110.20.148.173
# 9567  2017-10-20 12:27:50     8312    118.138.44.19
# 3463  2017-10-03 07:26:08     2960    60.240.238.31
# 23517 2017-10-14 07:09:36    20672     27.33.52.150
# 13926 2017-10-04 09:25:17    12211  203.219.146.184
# 1811  2017-10-05 09:02:06     1489     110.20.58.68
# 14717 2017-10-06 22:10:18    12909       1.144.96.4
#
#                                             Product_Name  \
# 2089   Drawstring Trunks,Train Core ID Tee,Milano Add...
# 9567                                          Dedalo Top
# 3463                             Sammy Neoprene Tote Bag
# 23517                                       The Original
# 13926  Bare Essential 3/4 Tights,DF Cool Breeze SS Te...
# 1811                            Stacey Plunge Mini Dress
# 14717  Ruby Crocheted Raffia Style,A-Line Skirt,Twigg...
#
#                                               Product_ID Is_First_Order  \
# ...

# %%
data["Country"].nunique()
# Out:
# 3

# %% [markdown]
# ## Univariate Analysis (Categorical)

# %%
def UVA_Cat(data, column, rot=0):
    """
    Function to plot countplot and pie chart for categorical variables.
    
    """
    for j, i in enumerate(column):
        
        #plt.subplot(2,1, j+1)
        
        # Setting the figure size
        plt.figure(figsize=(10,3), dpi=100)
    
    
        # ploting the barplot
        plt.subplot(1,2,1)
        g=sns.countplot(x=i, data= data)
        plt.title('Barplot for {}'.format(i), fontsize=14)
        plt.xticks(rotation=rot)
        #plt.rc('xtick',labelsize=8)
        plt.tight_layout()
        
        #ploting the pie chart 
        plt.subplot(1,2,2)
        plt.axis('equal')
        plt.pie(x= data[i].value_counts(), labels= data[i].value_counts().index, autopct='%0.1f%%', shadow=True)
        plt.title('Pie chart for {}'.format(i), fontsize=14)
        plt.tight_layout()
        plt.show()

# %%
# UVA_Cat(data, ['City_Code','Accomodation_Type'])

# %%
df = data.copy()

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
df["timestamp"] = df["timestamp"].astype('datetime64[ns]')

# %%
df["day"] = df.timestamp.dt.day

# %%
df["weekday"] = df.timestamp.dt.day_name()

# %%
df["hour"] = df.timestamp.dt.hour

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products',
#        'Payment_Mode', 'day', 'weekday', 'hour'],
#       dtype='object')

# %% [markdown]
# # User ID

# %%
duplicates_user_ID = df.pivot_table(index = ['user ID'], aggfunc ='size')

# %%
print(duplicates_user_ID)
# Out:
# user ID
# 0        121
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 44099      2
# 44100      1
# 44101      1
# 44102      1
# 44103      1
# Length: 44104, dtype: int64

# %%
df["User_Birthday"] = df["User_Birthday"].fillna("1800-01-01 00:00:00")

# %%
df["User_Birthday"] = df["User_Birthday"].replace(['undefined'] , '1800-01-01 00:00:00')

# %%
df["User_Birthday"] = pd.to_datetime(df["User_Birthday"])

df["User_Birthday"] = df["User_Birthday"].astype('datetime64[ns]')

# %%
df["User_Birthdate"] = df["User_Birthday"].dt.date

# %%
df["User_Birthyear"] = df["User_Birthday"].dt.year

# %%
df["User_Birthday"] = df["User_Birthday"].dt.day

# %%
df["present_date"] = df["timestamp"].dt.date

# %%
df["Age"] = (np.floor((df["present_date"] - df["User_Birthdate"]).dt.days / 365.25)).astype(int)

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products',
#        'Payment_Mode', 'day', 'weekday', 'hour', 'User_Birthdate',
#        'User_Birthyear', 'present_date', 'Age'],
#       dtype='object')

# %%
df.head()
# Out:
#             timestamp  user ID       ip_address                 Product_Name  \
# 0 2017-10-21 20:52:31        0    49.227.243.31                     Kendrick
# 1 2017-10-21 20:55:12        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2 2017-10-21 20:56:41        0    210.84.59.179               Classic Slides
# 3 2017-10-21 20:59:27        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4 2017-10-21 21:00:56        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS              0      female  cc@braintree                  1
# 1  MI329AC90OUB              1        male  pbi@afterpay                  1
# 2  SA849SH69SAK              1      female  cc@braintree                  1
# 3  SH045AA22AGR              0      female  pbi@afterpay                  1
# 4  MA146AA45RAK              0      female  cc@braintree                  1
#
# ...

# %%
df.to_csv("Fashion_data.csv", index=False)

# %%
df.head()
# Out:
#             timestamp  user ID       ip_address                 Product_Name  \
# 0 2017-10-21 20:52:31        0    49.227.243.31                     Kendrick
# 1 2017-10-21 20:55:12        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2 2017-10-21 20:56:41        0    210.84.59.179               Classic Slides
# 3 2017-10-21 20:59:27        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4 2017-10-21 21:00:56        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS              0      female  cc@braintree                  1
# 1  MI329AC90OUB              1        male  pbi@afterpay                  1
# 2  SA849SH69SAK              1      female  cc@braintree                  1
# 3  SH045AA22AGR              0      female  pbi@afterpay                  1
# 4  MA146AA45RAK              0      female  cc@braintree                  1
#
# ...

# %%
df["Product_ID"].unique()
# Out:
# array(['SE043SH31VBS', 'MI329AC90OUB', 'SA849SH69SAK', ...,
#        'JA108AA41NIK',
#        'NI126SA99UZK,BI358SH35RMI,AS787AA14UBL,AM901AA76WZV,AS787AA92JXV',
#        'BI358SH35RMI,AT049AA12IKP'], dtype=object)

# %%
df.head()
# Out:
#             timestamp  user ID       ip_address                 Product_Name  \
# 0 2017-10-21 20:52:31        0    49.227.243.31                     Kendrick
# 1 2017-10-21 20:55:12        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2 2017-10-21 20:56:41        0    210.84.59.179               Classic Slides
# 3 2017-10-21 20:59:27        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4 2017-10-21 21:00:56        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS              0      female  cc@braintree                  1
# 1  MI329AC90OUB              1        male  pbi@afterpay                  1
# 2  SA849SH69SAK              1      female  cc@braintree                  1
# 3  SH045AA22AGR              0      female  pbi@afterpay                  1
# 4  MA146AA45RAK              0      female  cc@braintree                  1
#
# ...

# %%
DataFrame = df[df.Revenue != "undefined"]

# %%
DataFrame.shape
# Out:
# (49984, 25)

# %%
DataFrame.to_csv("DATA.csv",index=False)

# %%
data = DataFrame.copy()

# %%
sum(data.Revenue)
# Out:
# 6699843.719999779

# %%
data.Product_ID.unique()
# Out:
# array(['SE043SH31VBS', 'MI329AC90OUB', 'SA849SH69SAK', ...,
#        'JA108AA41NIK',
#        'NI126SA99UZK,BI358SH35RMI,AS787AA14UBL,AM901AA76WZV,AS787AA92JXV',
#        'BI358SH35RMI,AT049AA12IKP'], dtype=object)
