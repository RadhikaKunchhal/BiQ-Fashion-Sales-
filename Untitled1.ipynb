# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
data = pd.read_csv("Fashion_Data.csv")

# %%
DATA = data[data.Revenue != "undefined"]

# %%
DATA.shape
# Out:
# (49984, 28)

# %%
df = DATA.copy()

# %%
df.Revenue = df.Revenue.astype('float')

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied'],
#       dtype='object')

# %%
df[["Sum_Of_Products" , "Unique_products"]] = df[["Sum_Of_Products" , "Unique_products"]].astype("int")

# %%
df.Revenue.sum()
# Out:
# 6699843.719999995

# %%
df[["Sum_Of_Products" , "Unique_products"]].sum()
# Out:
# Sum_Of_Products    101332
# Unique_products     98686
# dtype: int64

# %%
df[["Sum_Of_Products" , "Unique_products"]].mean()
# Out:
# Sum_Of_Products    2.027289
# Unique_products    1.974352
# dtype: float64

# %%
df["Revenue"].mean()
# Out:
# 134.03976712547572

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products',
#        'Payment_Mode', 'day', 'weekday', 'hour', 'User_Birthdate',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day'],
#       dtype='object')

# %%
df[["day" , "weekday" , "hour", "Payment_Type" , "Country_Province" , "Country"]].nunique()
# Out:
# day                 21
# weekday              7
# hour                24
# Payment_Type         4
# Country_Province     8
# Country              2
# dtype: int64

# %%
df["Hour_Day"].unique()
# Out:
# array(['Evening', 'Night', 'Morning', 'Afternoon'], dtype=object)

# %%
df["Payment_Type"].unique()
# Out:
# array(['cc@braintree', 'pbi@afterpay', 'paypal@braintree', 'NoPayment'],
#       dtype=object)

# %%
df["Payment_Mode"].value_counts()
# Out:
# BrainTree    23763
# Stripe       13178
# Paypal       12059
# NoPayment      984
# Name: Payment_Mode, dtype: int64

# %%
def UVA_Cat(data, column, rot=0):
    """
    Function to plot countplot and pie chart for categorical variables.
    
    """
    for j, i in enumerate(column):
        
        #plt.subplot(2,1, j+1)
        
        # Setting the figure size
        plt.figure(figsize=(10,3), dpi=100)
    
    
        # ploting the barplot
        plt.subplot(1,2,1)
        g=sns.countplot(x=i, data= data)
        plt.title('Barplot for {}'.format(i), fontsize=14)
        plt.xticks(rotation=rot)
        #plt.rc('xtick',labelsize=8)
        plt.tight_layout()
        
        #ploting the pie chart 
        plt.subplot(1,2,2)
        plt.axis('equal')
        plt.pie(x= data[i].value_counts(), labels= data[i].value_counts().index, autopct='%0.1f%%', shadow=True)
        plt.title('Pie chart for {}'.format(i), fontsize=14)
        plt.tight_layout()
        plt.show()

# %%
UVA_Cat(data, ['Country' , 'Country_Province' , 'Payment_Mode' , "Customer_Type"])

# %%
df[df["Country"] == "NZ"]["Country_Province"].unique()
# Out:
# array([nan, 'WA', 'NSW', 'QLD', 'VIC', 'TAS', 'NT', 'SA'], dtype=object)

# %%
df[df["Country"] == "AU"]["Country_Province"].unique()
# Out:
# array(['VIC', 'NSW', 'ACT', 'TAS', nan, 'QLD', 'SA', 'WA', 'NT'],
#       dtype=object)

# %%
df.head()
# Out:
#           timestamp  user ID       ip_address                 Product_Name  \
# 0  21-10-2017 20:52        0    49.227.243.31                     Kendrick
# 1  21-10-2017 20:55        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2  21-10-2017 20:56        0    210.84.59.179               Classic Slides
# 3  21-10-2017 20:59        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4  21-10-2017 21:00        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS              0      female  cc@braintree                  1
# 1  MI329AC90OUB              1        male  pbi@afterpay                  1
# 2  SA849SH69SAK              1      female  cc@braintree                  1
# 3  SH045AA22AGR              0      female  pbi@afterpay                  1
# 4  MA146AA45RAK              0      female  cc@braintree                  1
#
# ...

# %%
df["user ID"].value_counts()
# Out:
# 0        121
# 42189     96
# 6037      70
# 34691     58
# 32457     14
#         ...
# 23256      1
# 8919       1
# 10966      1
# 13013      1
# 34817      1
# Name: user ID, Length: 44089, dtype: int64

# %%
df["ip_address"].value_counts()
# Out:
# 49.255.235.25      202
# 210.5.112.34       104
# 180.232.79.218      40
# 108.171.134.165     39
# 203.11.225.5        35
#                   ...
# 49.195.143.252       1
# 106.68.98.64         1
# 122.62.17.206        1
# 202.61.122.35        1
# 124.170.27.251       1
# Name: ip_address, Length: 41808, dtype: int64

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode'],
#       dtype='object')

# %%
New = df[df["Customer_Type"] == "New"]

# %%
New["user ID"].value_counts()
# Out:
# 0        40
# 32457    10
# 34181     5
# 12758     5
# 42527     4
#          ..
# 2652      1
# 8793      1
# 43608     1
# 37463     1
# 6183      1
# Name: user ID, Length: 11207, dtype: int64

# %%
Old = df[df["Customer_Type"] == "Old"]

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied'],
#       dtype='object')

# %%
UVA_Cat(data, ['User_Gender'])

# %%
UVA_Cat(Old, ['User_Gender'])

# %%
UVA_Cat(New, ['User_Gender'])

# %%
df.shape[0]
# Out:
# 49984

# %%
UVA_Cat(data, ['Country'])

# %%
UVA_Cat(Old, ['Country']) , UVA_Cat(New, ['Country'])
# Out:
# (None, None)

# %%
UVA_Cat(Old, ['Payment_Mode']) , UVA_Cat(Old, ['Payment_Mode']) , UVA_Cat(New, ['Payment_Mode'])
# Out:
# (None, None, None)

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type'],
#       dtype='object')

# %%
df.Unique_products.unique()
# Out:
# array([ 1,  2,  3,  5,  7,  4,  6,  9, 13,  8, 10, 11, 14, 15, 17, 25, 12,
#        18, 19, 36, 23, 16, 33, 24, 22, 20, 28, 21, 29], dtype=int64)

# %%
UVA_Cat(df, ['Unique_products']) , UVA_Cat(Old, ['Unique_products']), UVA_Cat(New, ['Unique_products'])
# Out:
# (None, None, None)

# %%
UVA_Cat(df, ['Sum_Of_Products']) , UVA_Cat(Old, ['Sum_Of_Products']), UVA_Cat(New, ['Sum_Of_Products'])
# Out:
# (None, None, None)

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type'],
#       dtype='object')

# %%
df.isna().mean()
# Out:
# timestamp             0.000000
# user ID               0.000000
# ip_address            0.000000
# Product_Name          0.000000
# Product_ID            0.000000
# Is_First_Order        0.000000
# User_Gender           0.023488
# Payment_Type          0.000000
# Number_of_Products    0.000000
# Order_Coupon_Code     0.000000
# City                  0.006742
# Country_Province      0.083627
# User_Birthday         0.000000
# Country               0.000000
# Revenue               0.000000
# Sum_Of_Products       0.000000
# Unique_products       0.000000
# day                   0.000000
# weekday               0.000000
# hour                  0.000000
# User_Birthdate        0.000000
# User_Birthyear        0.000000
# present_date          0.000000
# Age                   0.000000
# Hour_Day              0.000000
# Payment_Mode          0.000000
# Customer_Type         0.000000
# Coupon_Applied        0.000000
# dtype: float64

# %%
UVA_Cat(df, ['Coupon_Applied']) , UVA_Cat(Old, ['Coupon_Applied']), UVA_Cat(New, ['Coupon_Applied'])
# Out:
# (None, None, None)

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied'],
#       dtype='object')

# %%
UVA_Cat(df, ['Coupon_Applied']) , UVA_Cat(Old, ['Coupon_Applied']), UVA_Cat(New, ['Coupon_Applied'])

# %%
df.Age.unique()
# Out:
# array([ 24, 217,  46,  54,  22,  40,  30,  38,  34,  68,  25,  23,  49,
#         47,  32,  20,  21,  31,  37,  19,  56,  48,  33,  29,  28,  36,
#         41,  15,  44,  26,  27,  39,  52,  50,  35,  45,  42,  55,  51,
#         53,  43,   1, 117,  16,  18,  57,  14,  64,  73,  61,   8,  58,
#          2,  69,  17,  62,  76,  63,  59,   5,  60,  67,  13,  65,   0,
#          9,  66,  70,  80,  71,  72,  74,   4,   3,  82,  -1,  12],
#       dtype=int64)

# %%
df[df.Age == 0]
# Out:
#               timestamp  user ID       ip_address  \
# 8623   03-10-2017 08:53     7500   27.252.195.172
# 11703  02-10-2017 15:31    10233    106.68.212.12
# 18270  09-10-2017 09:08    16049  165.228.227.106
# 18479  07-10-2017 04:00    16232   110.20.101.157
# 24880  08-10-2017 10:25    21913   49.189.245.218
# 25538  10-10-2017 03:35    22495  120.151.101.125
# 30229  04-10-2017 02:52    26650    122.60.69.216
# 30230  04-10-2017 21:53    26650    130.123.29.17
# 30833  05-10-2017 02:21    27205     49.255.190.2
# 31705  05-10-2017 02:56    27977    203.160.3.134
# 32726  16-10-2017 03:00    28879    103.231.169.4
# 33664  19-10-2017 21:14    29722    49.181.168.69
# 34413  21-10-2017 07:05    30379   118.92.202.217
# 37191  20-10-2017 10:28    32849    49.197.203.75
# 40837  08-10-2017 05:10    36011       58.6.203.8
# 41965  06-10-2017 08:33    37029    101.188.84.85
# 45507  01-10-2017 23:37    40210   121.211.192.81
# 49685  04-10-2017 03:00    43840     103.44.165.1
#
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied'],
#       dtype='object')

# %%
df[df.User_Birthyear == 1800]
# Out:
#               timestamp  user ID       ip_address  \
# 1      21-10-2017 20:55        0  111.220.172.119
# 2      21-10-2017 20:56        0    210.84.59.179
# 3      21-10-2017 20:59        0    59.167.79.119
# 4      21-10-2017 21:00        0    1.129.107.188
# 6      21-10-2017 21:08        0   49.180.132.205
# ...                 ...      ...              ...
# 49976  11-10-2017 10:24    44097     202.67.95.53
# 49977  17-10-2017 22:26    44098     114.74.65.38
# 49978  10-10-2017 01:37    44099   203.86.203.216
# 49979  11-10-2017 08:26    44099   203.86.203.216
# 49980  18-10-2017 13:17    44100   141.168.65.138
#
#                                             Product_Name  \
# 1                               Smartwatch Bradshaw Gold
# 2                                         Classic Slides
# 3                            Bonaire Flared Sleeve Tunic
# 4                             Tall Tales Man Style Pants
# 6      Sorrento Stripe Roll Band Brief,SPF 50  Long S...
# ...

# %%
27275/df.shape[0]
# Out:
# 0.5456746158770807

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied'],
#       dtype='object')

# %%
df.Order_Coupon_Code.unique()
# Out:
# array(['YAY15', 'Zero', 'NCSke2ou8', ..., 'nlsswyj2Sq', '25SHOPU95cHi',
#        'NCSUBsARA'], dtype=object)

# %%
coupon = pd.DataFrame(df.Order_Coupon_Code.value_counts().reset_index(name="frequency"))

# %%
coupon
# Out:
#                  index  frequency
# 0                 Zero      38105
# 1               SPRING       3849
# 2            10UNIDAYS       1632
# 3                YAY15       1046
# 4             BEICONIC        615
# ...                ...        ...
# 3080       20MLBEoPhVi          1
# 3081         HBDkRqE3d          1
# 3082         HBDY0wRgD          1
# 3083         HBDEWWiFr          1
# 3084  ICONUTF20PM75wfq          1
#
# [3085 rows x 2 columns]

# %%
def coupon_code(coupon):
    if (coupon['frequency'] == 38105):
        return "No_Coupon"
    elif (coupon['frequency'] >= 2):
        return "General"
    else :
        return "Special"

coupon['Coupon_Type'] = coupon.apply(coupon_code, axis=1)

# %%
coupon
# Out:
#                  index  frequency Coupon_Type
# 0                 Zero      38105   No_Coupon
# 1               SPRING       3849     General
# 2            10UNIDAYS       1632     General
# 3                YAY15       1046     General
# 4             BEICONIC        615     General
# ...                ...        ...         ...
# 3080       20MLBEoPhVi          1     Special
# 3081         HBDkRqE3d          1     Special
# 3082         HBDY0wRgD          1     Special
# 3083         HBDEWWiFr          1     Special
# 3084  ICONUTF20PM75wfq          1     Special
#
# [3085 rows x 3 columns]

# %%
coupon[coupon["frequency"] == 1]
# Out:
#                  index  frequency Coupon_Type
# 270         nlssw60ZxE          1     Special
# 271       25SHOP6dph7k          1     Special
# 272          HBDsZWARY          1     Special
# 273          HBDknJDR7          1     Special
# 274         nlssglYZbh          1     Special
# ...                ...        ...         ...
# 3080       20MLBEoPhVi          1     Special
# 3081         HBDkRqE3d          1     Special
# 3082         HBDY0wRgD          1     Special
# 3083         HBDEWWiFr          1     Special
# 3084  ICONUTF20PM75wfq          1     Special
#
# [2815 rows x 3 columns]

# %%
coupon.rename(columns= {'index':'Order_Coupon_Code' , 'frequency':'frequency' , 'Coupon_Type':'Coupon_Type'},inplace=True)

# %%
coupon
# Out:
#      Order_Coupon_Code  frequency Coupon_Type
# 0                 Zero      38105   No_Coupon
# 1               SPRING       3849     General
# 2            10UNIDAYS       1632     General
# 3                YAY15       1046     General
# 4             BEICONIC        615     General
# ...                ...        ...         ...
# 3080       20MLBEoPhVi          1     Special
# 3081         HBDkRqE3d          1     Special
# 3082         HBDY0wRgD          1     Special
# 3083         HBDEWWiFr          1     Special
# 3084  ICONUTF20PM75wfq          1     Special
#
# [3085 rows x 3 columns]

# %%
DATA = pd.merge(DATA,coupon,how='left',on=['Order_Coupon_Code'])

# %%
DATA.drop(['frequency'] , axis = 1 , inplace = True)

# %%
DATA.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied',
#        'Coupon_Type'],
#       dtype='object')

# %%
DATA.head()
# Out:
#           timestamp  user ID       ip_address                 Product_Name  \
# 0  21-10-2017 20:52        0    49.227.243.31                     Kendrick
# 1  21-10-2017 20:55        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2  21-10-2017 20:56        0    210.84.59.179               Classic Slides
# 3  21-10-2017 20:59        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4  21-10-2017 21:00        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID  Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS               0      female  cc@braintree                  1
# 1  MI329AC90OUB               1        male  pbi@afterpay                  1
# 2  SA849SH69SAK               1      female  cc@braintree                  1
# 3  SH045AA22AGR               0      female  pbi@afterpay                  1
# 4  MA146AA45RAK               0      female  cc@braintree                  1
#
# ...

# %%
df = DATA.copy()

# %%
Old = df[df["Customer_Type"] == "Old"]

# %%
New = df[df["Customer_Type"] == "New"]

# %%
UVA_Cat(df , ['Coupon_Type']) , UVA_Cat(Old, ['Coupon_Type']), UVA_Cat(New , ['Coupon_Type'])
# Out:
# (None, None, None)

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied',
#        'Coupon_Type'],
#       dtype='object')

# %%
UVA_Cat(df , ['Country_Province']) , UVA_Cat(Old, ['Country_Province']), UVA_Cat(New , ['Country_Province'])
# Out:
# (None, None, None)

# %%
revenue versis general coupon general revenue , country gender wise above graph

# %%
df.Revenue.sum() / df.shape[0]
# Out:
# 134.03976712548015

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied',
#        'Coupon_Type'],
#       dtype='object')

# %%
import re

def split_it(product):
    return re.findall(r'\w\w', product)

df['Product_type'] = df['Product_ID'].apply(split_it)

# %%
df['Product_type'] = df["Product_ID"].astype(str).str[:2]

# %%
df.head()
# Out:
#           timestamp  user ID       ip_address                 Product_Name  \
# 0  21-10-2017 20:52        0    49.227.243.31                     Kendrick
# 1  21-10-2017 20:55        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2  21-10-2017 20:56        0    210.84.59.179               Classic Slides
# 3  21-10-2017 20:59        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4  21-10-2017 21:00        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID  Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS               0      female  cc@braintree                  1
# 1  MI329AC90OUB               1        male  pbi@afterpay                  1
# 2  SA849SH69SAK               1      female  cc@braintree                  1
# 3  SH045AA22AGR               0      female  pbi@afterpay                  1
# 4  MA146AA45RAK               0      female  cc@braintree                  1
#
# ...

# %%
df.Product_type.nunique()
# Out:
# 205

# %%
df.to_csv("DATA.csv" , index = False)

# %%
df.head()
# Out:
#           timestamp  user ID       ip_address                 Product_Name  \
# 0  21-10-2017 20:52        0    49.227.243.31                     Kendrick
# 1  21-10-2017 20:55        0  111.220.172.119     Smartwatch Bradshaw Gold
# 2  21-10-2017 20:56        0    210.84.59.179               Classic Slides
# 3  21-10-2017 20:59        0    59.167.79.119  Bonaire Flared Sleeve Tunic
# 4  21-10-2017 21:00        0    1.129.107.188   Tall Tales Man Style Pants
#
#      Product_ID  Is_First_Order User_Gender  Payment_Type Number_of_Products  \
# 0  SE043SH31VBS               0      female  cc@braintree                  1
# 1  MI329AC90OUB               1        male  pbi@afterpay                  1
# 2  SA849SH69SAK               1      female  cc@braintree                  1
# 3  SH045AA22AGR               0      female  pbi@afterpay                  1
# 4  MA146AA45RAK               0      female  cc@braintree                  1
#
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied',
#        'Coupon_Type', 'Product_type'],
#       dtype='object')

# %%
Single = data[data.Unique_products == 1]
Multiple = data[data.Unique_products !=1]

# %%
UVA_Cat(Single, ['Customer_Type']) , UVA_Cat(Multiple, ['Customer_Type'])
# Out:
# (None, None)

# %%
df.columns
# Out:
# Index(['timestamp', 'user ID', 'ip_address', 'Product_Name', 'Product_ID',
#        'Is_First_Order', 'User_Gender', 'Payment_Type', 'Number_of_Products',
#        'Order_Coupon_Code', 'City', 'Country_Province', 'User_Birthday',
#        'Country', 'Revenue', 'Sum_Of_Products', 'Unique_products', 'day',
#        'weekday', 'hour', 'User_Birthdate', 'User_Birthyear', 'present_date',
#        'Age', 'Hour_Day', 'Payment_Mode', 'Customer_Type', 'Coupon_Applied',
#        'Coupon_Type', 'Product_type'],
#       dtype='object')

# %%
UVA_Cat(df,['Hour_Day']) , UVA_Cat(Single,['Hour_Day']), UVA_Cat(Multiple,['Hour_Day'])
# Out:
# (None, None, None)

# %%
data = pd.read_csv("Final data.csv")

# %%
data.head()
# Out:
#    user ID       ip_address    Product_ID User_Gender  Payment_Type  \
# 0        0    49.227.243.31  SE043SH31VBS      female  cc@braintree
# 1        0  111.220.172.119  MI329AC90OUB        male  pbi@afterpay
# 2        0    210.84.59.179  SA849SH69SAK      female  cc@braintree
# 3        0    59.167.79.119  SH045AA22AGR      female  pbi@afterpay
# 4        0    1.129.107.188  MA146AA45RAK      female  cc@braintree
#
#   Country_Province  User_Birthday Country  Revenue  Sum_Of_Products  ...  \
# 0              NaN              5      NZ   212.50                1  ...
# 1              VIC              1      AU   526.36                1  ...
# 2              VIC              1      AU    77.23                1  ...
# 3              NSW              1      AU   190.91                1  ...
# 4              NSW              1      AU   204.09                1  ...
#
#    present_date  Age Hour_Day  Payment_Mode  Customer_Type Coupon_Applied  \
# ...

# %%
data.columns
# Out:
# Index(['user ID', 'ip_address', 'Product_ID', 'User_Gender', 'Payment_Type',
#        'Country_Province', 'User_Birthday', 'Country', 'Revenue',
#        'Sum_Of_Products', 'Unique_products', 'day', 'weekday', 'hour',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day', 'Payment_Mode',
#        'Customer_Type', 'Coupon_Applied', 'Coupon_Type', 'Product_type',
#        'Purchase_day', 'Type of Shopper', 'Age_group'],
#       dtype='object')

# %%
sns.barplot(x="" , y="Sum_Of_Products" , data=data)
# Out:
# <AxesSubplot:xlabel='Type of Shopper', ylabel='Sum_Of_Products'>

# %%
data.columns
# Out:
# Index(['user ID', 'ip_address', 'Product_ID', 'User_Gender', 'Payment_Type',
#        'Country_Province', 'User_Birthday', 'Country', 'Revenue',
#        'Sum_Of_Products', 'Unique_products', 'day', 'weekday', 'hour',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day', 'Payment_Mode',
#        'Customer_Type', 'Coupon_Applied', 'Coupon_Type', 'Product_type',
#        'Purchase_day', 'Type of Shopper'],
#       dtype='object')

# %%
data = pd.read_csv("Final data.csv")

# %%
UVA_Cat(data,["User_Gender"]) , UVA_Cat(Old,["User_Gender"]) , UVA_Cat(New,["User_Gender"])
# Out:
# (None, None, None)

# %%
UVA_Cat(data , ['Age_group']), UVA_Cat(Old , ['Age_group']), UVA_Cat(New , ['Age_group'])
# Out:
# (None, None, None)

# %%
data.columns
# Out:
# Index(['user ID', 'ip_address', 'Product_ID', 'User_Gender', 'Payment_Type',
#        'Country_Province', 'User_Birthday', 'Country', 'Revenue',
#        'Sum_Of_Products', 'Unique_products', 'day', 'weekday', 'hour',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day', 'Payment_Mode',
#        'Customer_Type', 'Coupon_Applied', 'Coupon_Type', 'Product_type',
#        'Purchase_day', 'Type of Shopper', 'Age_group'],
#       dtype='object')

# %%
New = data[data["Customer_Type"] == "New"]

# %%
Old = data[data["Customer_Type"] == "Old"]

# %%
Single = data[data["Type of Shopper"] == "Single User"]

# %%
Multiple = data[data["Type of Shopper"] == "Multiple User"]

# %%
data["Type of Shopper"].value_counts()
# Out:
# Single User      26284
# Multiple User    23700
# Name: Type of Shopper, dtype: int64

# %%
UVA_Cat(data , ['User_Gender']), UVA_Cat(Single , ['Customer_Type']), UVA_Cat(Multiple , ['Customer_Type'])
# Out:
# (None, None, None)

# %%
data.columns
# Out:
# Index(['user ID', 'ip_address', 'Product_ID', 'User_Gender', 'Payment_Type',
#        'Country_Province', 'User_Birthday', 'Country', 'Revenue',
#        'Sum_Of_Products', 'Unique_products', 'day', 'weekday', 'hour',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day', 'Payment_Mode',
#        'Customer_Type', 'Coupon_Applied', 'Coupon_Type', 'Product_type',
#        'Purchase_day', 'Type of Shopper', 'Age_group'],
#       dtype='object')

# %%
data.head()
# Out:
#    user ID       ip_address    Product_ID User_Gender  Payment_Type  \
# 0        0    49.227.243.31  SE043SH31VBS      female  cc@braintree
# 1        0  111.220.172.119  MI329AC90OUB        male  pbi@afterpay
# 2        0    210.84.59.179  SA849SH69SAK      female  cc@braintree
# 3        0    59.167.79.119  SH045AA22AGR      female  pbi@afterpay
# 4        0    1.129.107.188  MA146AA45RAK      female  cc@braintree
#
#   Country_Province  User_Birthday Country  Revenue  Sum_Of_Products  ...  Age  \
# 0              NaN              5      NZ   212.50                1  ...   24
# 1              VIC              1      AU   526.36                1  ...  217
# 2              VIC              1      AU    77.23                1  ...  217
# 3              NSW              1      AU   190.91                1  ...  217
# 4              NSW              1      AU   204.09                1  ...  217
#
#    Hour_Day Payment_Mode  Customer_Type  Coupon_Applied Coupon_Type  \
# ...

# %%
UVA_Cat(data , ["Payment_Mode"])

# %%
data.columns
# Out:
# Index(['user ID', 'ip_address', 'Product_ID', 'User_Gender', 'Payment_Type',
#        'Country_Province', 'User_Birthday', 'Country', 'Revenue',
#        'Sum_Of_Products', 'Unique_products', 'day', 'weekday', 'hour',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day', 'Customer_Type',
#        'Coupon_Applied', 'Coupon_Type', 'Product_type', 'Purchase_day',
#        'Type of Shopper', 'Age_group', 'Payment_Mode'],
#       dtype='object')

# %%
UVA_Cat(data , ["Hour_Day"]) , UVA_Cat(Female, ["Hour_Day"])  , UVA_Cat(Male , ["Hour_Day"]) , UVA_Cat(NZ , ["Hour_Day"])  , UVA_Cat(AUS , ["Hour_Day"])
# Out:
# (None, None, None, None, None)

# %%
Female = data[data["User_Gender"] == "female"]

# %%
Male = data[data["User_Gender"] == "male"]

# %%
data.Country.unique()
# Out:
# array(['NZ', 'AU'], dtype=object)

# %%
NZ = data[data["Country"] == "NZ"]

# %%
AUS = data[data["Country"] == "AU"]

# %%
UVA_Cat(data , ["Purchase_day"]) , UVA_Cat(Female, ["Purchase_day"])  , UVA_Cat(Male , ["Purchase_day"]) , UVA_Cat(NZ , ["Purchase_day"])  , UVA_Cat(AUS , ["Purchase_day"])
# Out:
# (None, None, None, None, None)

# %%
UVA_Cat(data , ["weekday"]) , UVA_Cat(Female, ["weekday"])  , UVA_Cat(Male , ["weekday"]) , UVA_Cat(NZ , ["weekday"])  , UVA_Cat(AUS , ["weekday"])
# Out:
# (None, None, None, None, None)

# %%
data.columns
# Out:
# Index(['user ID', 'ip_address', 'Product_ID', 'User_Gender', 'Payment_Type',
#        'Country_Province', 'User_Birthday', 'Country', 'Revenue',
#        'Sum_Of_Products', 'Unique_products', 'day', 'weekday', 'hour',
#        'User_Birthyear', 'present_date', 'Age', 'Hour_Day', 'Customer_Type',
#        'Coupon_Applied', 'Coupon_Type', 'Product_type', 'Purchase_day',
#        'Type of Shopper', 'Age_group', 'Payment_Mode'],
#       dtype='object')

# %%
Night = data[data["Hour_Day"] == "Night"]
Morning = data[data["Hour_Day"] == "Morning"]
Evening = data[data["Hour_Day"] == "Evening"]
Afternoon = data[data["Hour_Day"] == "Afternoon"]
New = data[data["Customer_Type"] == "New"]
Old = data[data["Customer_Type"] == "Old"]
Single = data[data["Type of Shopper"] == "Single User"]
Multiple = data[data["Type of Shopper"] == "Multiple User"]

# %%
UVA_Cat(data, ["Coupon_Applied"]), UVA_Cat(New, ["Coupon_Applied"]),UVA_Cat(Old, ["Coupon_Applied"]), UVA_Cat(Single, ["Coupon_Applied"]), UVA_Cat(Multiple, ["Coupon_Applied"])
# Out:
# (None, None, None, None, None)

# %%
UVA_Cat(data, ["Coupon_Type"]), UVA_Cat(New, ["Coupon_Type"]),UVA_Cat(Old, ["Coupon_Type"]), UVA_Cat(Single, ["Coupon_Type"]), UVA_Cat(Multiple, ["Coupon_Type"])
# Out:
# (None, None, None, None, None)

# %%
UVA_Cat(New, ["Type of Shopper"]) , UVA_Cat(Old, ["Type of Shopper"])
# Out:
# (None, None)

# %%
New_Single = New[New["Type of Shopper"] == "Single User"]
New_Multiple = New[New["Type of Shopper"] == "Multiple User"]

# %%
UVA_Cat(New_Single , ["Coupon_Applied"]) , UVA_Cat(New_Single , ["Coupon_Type"]) , UVA_Cat(New_Multiple , ["Coupon_Applied"]) , UVA_Cat(New_Multiple , ["Coupon_Type"])
# Out:
# (None, None, None, None)

# %%
UVA_Cat(New_Single , ["Payment_Mode"]), UVA_Cat(New_Multiple , ["Payment_Mode"])
# Out:
# (None, None)

# %%
UVA_Cat(Single , ["User_Gender"]),UVA_Cat(Multiple , ["User_Gender"])
# Out:
# (None, None)
